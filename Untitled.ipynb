# %%
### Role: You are an expert Project Management Officer (PMO).
### Task: Summarize the following Project Status Report.
### Context: This summary is for the Stakeholder Monthly Review to identify if the project is on track.
### Constraints:
## Summarize in 150 words or less.
Focus on blockers and missed deadlines.
Use a concise, professional, and direct tone.
### Output:
Project Name & Health Status (Green/Yellow/Red)
Top 3 Risks/Blockers
Key Accomplishments
Action Items for Stakeholders
### Report Data:
[Insert Document Text Here]
