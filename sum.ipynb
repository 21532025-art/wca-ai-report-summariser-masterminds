# %%
import os



API_KEY = os.getenv("OPENAI_API_KEY")
print(API_KEY)
# Out:
# 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
