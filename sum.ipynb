# %%
# Out:
# === AI Report Summariser ===
# Generating summary...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 88
#      86 # Run program
#      87 if __name__ == "__main__":
# ---> 88     main()
#
# Cell In[6], line 81, in main()
#      78 print("\nGenerating summary...\n")
#      80 # Get summary
# ---> 81 summary = summarize_text(text)
#      83 print("=== Executive Summary ===")
#      84 print(summary)
#
# Cell In[6], line 60, in summarize_text(text)
#      57 result = response.json()
#      59 # Extract summary from JSON
# ---> 60 return result["choices"][0]["message"]["content"]
#
# KeyError: 'choices'
